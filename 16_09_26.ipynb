# %%
print("Hello, World")
# Out:
# Hello, World

# %%
print("*\n"*3)
# Out:
# *
# *
# *

# %%
print("*"*3)
# Out:
# ***

# %%
print("*" * 3, sep="\n")
# Out:
# ***

# %%
name="SHIVU"
print(name)
# Out:
# SHIVU
